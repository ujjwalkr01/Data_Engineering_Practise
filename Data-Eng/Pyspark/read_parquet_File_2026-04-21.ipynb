# %%
/Volumes/workspace/default/my_volume/part-r-00000-1a9822ba-b8fb-4d8e-844a-ea30d0801b9e.gz.parquet

# %%
df=spark.read.parquet("/Volumes/workspace/default/my_volume/part-r-00000-1a9822ba-b8fb-4d8e-844a-ea30d0801b9e.gz.parquet")
df.show()
