# %%
print("Welcome to Python programming");
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print("Welcome to Python programming");
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1481, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1523, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1324, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1961, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# ...

# %%
print("Hello world!");
# Out:
# Hello world!

# %%
name="Ujjwal"
age=26
isStud=False
height=5.9

print(name,age,isStud,height);
print(type(name));
print(type(age));
print(type(isStud));
print(type(height));
# Out:
# Ujjwal 26 False 5.9
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>

# %%
a=b=c=100;
print(a,b,c);

a,b,c=1,2,3
print(a,b,c);
# Out:
# 100 100 100
# 1 2 3

# %%
name=input("Enter your name");
print(name);

age=input("Enter your age:");
print(age);
print(type(age));
# by default input always store string values so we have to convert the values accordingly.
#to convert string to any data type we have to type cast it. 

weight=int(input("enter your weight"));
print(weight);
print(type(weight));
# Out:
# ujjwal
# 24
# <class 'str'>
# 75
# <class 'int'>

# %%
#BMI Calculator
weight=int(input("enter your weight in kgs:"));
height=float(input("enter your height in m:"));

print(f"The BMI of the person is :{weight/(height ** 2):.2f}");
# Out:
# The BMI of the person is :24.49
